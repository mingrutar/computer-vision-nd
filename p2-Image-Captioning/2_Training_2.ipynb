# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** In the CNN-RNN architecture, the CNN is the encoder and it outputs embedded image feature vector. We use pre-trained convolution network ResNet50, stripped the last layer, then add a linear layer to output the desirable vector size for RNN. The RNN is constructed with an Embedding, a LSTM, a Dropout and a Linear layers. See archtecture diagram in 1_Preliminaries notebook and code implementation in mpdel.py
#
# I've tried `batch_size` 32 and 64 and settled on 32 because it has higher accuracy. Smaller batch_size introduces more noise what helps training.
#
# I've experimented `vocab_threshold` 2, 3, 4, 5. I found vocab_threshold = 2 contains significantly more words than vocab_threshold = 3, so I settled with vocab_threshold = 2
#
# I set `hidden_size` double of `embed_size` for learning. I like to try embed_size = 512, but I run out time for the 1st submission.
#
# One LSTM layer does not performce as well as 2 layers.
#
# I added `drop_prob` variable but set as 0.0 because at one point, the network loss rate jumpped from around 4+ to 9+, and I tried to restore to previous states. As a result, the `drop_prob` was set tp 0.0
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** The transform_train makes good sense to me. Since the CNN input image size is 224x224, resizing an image to 256 ensure that we can crop the image to desireble size with little loss. If I had time, I may experiment various values for Normalizing. But so far the values performed well.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** Yes, I think that the params is a good choice. The encoder uses pre-trained ResNet, plus a linear layer. We can only adjust the last layer, which is 'embed' layer. Since I designed the decoder, all weights are adjusted.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** The selected optimizer is Adam with started learning rate 0.001. I have experiemented other combinations and end up with this one. When learning rates are too low, the network stops learning at certain points. Optimizer SGD does not adapt learning rate. In my experiment, the network does not converge well.
# I found this article online https://shaoanlu.wordpress.com/2017/05/29/sgd-all-which-one-is-the-best-optimizer-dogs-vs-cats-toy-experiment/. The results of ShaoAnLu's experiments with various optimizers is consistent with mine in term of Adam vs SGD.

# %%
% load_ext autoreload
% autoreload 2

# %%
import os
import torch
import torch.nn as nn
from torchvision import transforms
import sys

dataDir = os.environ.get("COCOAPI") if "COCOAPI" in os.environ else '/opt/cocoapi'
#sys.path.append('/opt/cocoapi/PythonAPI')
sys.path.append(os.path.join(dataDir, 'PythonAPI'))

# sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32            # batch size
vocab_threshold = 2        # minimum word count threshold
vocab_from_file = True     # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 768          # number of features in hidden state of the RNN decoder
num_layers = 3             # number layers
drop_prob = 0.2            # drop out
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100         # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file,
                         cocoapi_loc=os.path.dirname(dataDir))

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size, num_layers=num_layers, dropout=drop_prob)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device=", device)
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
#optimizer = torch.optim.SGD(params, lr=0.1)

# Set the total number of training steps per epoch.
#total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
#   0%|          | 0/414113 [00:00<?, ?it/s]
# Done (t=0.85s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [00:30<00:00, 13369.04it/s]
# device= cuda

# %%
# TODO #4: Define the optimizer.
learning_rate = 0.001
# learning_rate = 0.0008
optimizer = torch.optim.Adam(params, lr=learning_rate)
# optimizer = torch.optim.SGD(params, lr=learning_rate)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
# response = requests.request("GET", 
#                             "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
#                             headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
#             requests.request("POST", 
#                              "https://nebula.udacity.com/api/v1/remote/keep-alive", 
#                              headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % \
        (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)

    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models2', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models2', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/12942], Loss: 3.3413, Perplexity: 28.2560
# Epoch [1/3], Step [200/12942], Loss: 3.5243, Perplexity: 33.9291
# Epoch [1/3], Step [300/12942], Loss: 3.3782, Perplexity: 29.3180
# Epoch [1/3], Step [400/12942], Loss: 3.2350, Perplexity: 25.4073
# Epoch [1/3], Step [500/12942], Loss: 3.3477, Perplexity: 28.4367
# Epoch [1/3], Step [600/12942], Loss: 3.2529, Perplexity: 25.8650
# Epoch [1/3], Step [700/12942], Loss: 3.0286, Perplexity: 20.6683
# Epoch [1/3], Step [800/12942], Loss: 2.9437, Perplexity: 18.9866
# Epoch [1/3], Step [900/12942], Loss: 2.8673, Perplexity: 17.5895
# Epoch [1/3], Step [1000/12942], Loss: 3.3112, Perplexity: 27.4181
# Epoch [1/3], Step [1100/12942], Loss: 2.7021, Perplexity: 14.9104
# Epoch [1/3], Step [1200/12942], Loss: 3.2106, Perplexity: 24.7950
# Epoch [1/3], Step [1300/12942], Loss: 2.7300, Perplexity: 15.3331
# Epoch [1/3], Step [1400/12942], Loss: 2.9169, Perplexity: 18.48390
# Epoch [1/3], Step [1500/12942], Loss: 2.8497, Perplexity: 17.2819
# Epoch [1/3], Step [1600/12942], Loss: 2.7067, Perplexity: 14.9801
# Epoch [1/3], Step [1700/12942], Loss: 2.5517, Perplexity: 12.8293
# Epoch [1/3], Step [1800/12942], Loss: 2.7105, Perplexity: 15.0361
# Epoch [1/3], Step [1900/12942], Loss: 3.0041, Perplexity: 20.1678
# Epoch [1/3], Step [2000/12942], Loss: 2.7985, Perplexity: 16.4199
# Epoch [1/3], Step [2100/12942], Loss: 2.7039, Perplexity: 14.9377
# Epoch [1/3], Step [2200/12942], Loss: 2.7575, Perplexity: 15.7596
# Epoch [1/3], Step [2300/12942], Loss: 3.2619, Perplexity: 26.0978
# Epoch [1/3], Step [2400/12942], Loss: 2.4799, Perplexity: 11.9398
# Epoch [1/3], Step [2500/12942], Loss: 3.1187, Perplexity: 22.6174
# Epoch [1/3], Step [2600/12942], Loss: 3.2136, Perplexity: 24.8694
# Epoch [1/3], Step [2700/12942], Loss: 2.5335, Perplexity: 12.5976
# Epoch [1/3], Step [2800/12942], Loss: 2.6945, Perplexity: 14.7980
# Epoch [1/3], Step [2900/12942], Loss: 2.8124, Perplexity: 16.6498
# Epoch [1/3], Step [3000/12942], Loss: 2.5450, Perplexity: 12.7435
# Epoch [1/3], Step [3100/12942], Loss: 2.6969, Perplexity: 14.8338
# Epoch [1/3], Step [3200/12942], Loss: 2.4996, Perplexity: 12.1779
# Epoch [1/3], Step [3300/12942], Loss: 2.6014, Perplexity: 13.4831
# Epoch [1/3], Step [3400/12942], Loss: 2.8600, Perplexity: 17.4613
# Epoch [1/3], Step [3500/12942], Loss: 2.7141, Perplexity: 15.0915
# Epoch [1/3], Step [3600/12942], Loss: 2.7233, Perplexity: 15.23028
# Epoch [1/3], Step [3700/12942], Loss: 2.7647, Perplexity: 15.8747
# Epoch [1/3], Step [3800/12942], Loss: 2.8399, Perplexity: 17.1142
# Epoch [1/3], Step [3900/12942], Loss: 2.9543, Perplexity: 19.1883
# Epoch [1/3], Step [4000/12942], Loss: 2.5569, Perplexity: 12.8960
# Epoch [1/3], Step [4100/12942], Loss: 2.9618, Perplexity: 19.3331
# Epoch [1/3], Step [4200/12942], Loss: 2.3918, Perplexity: 10.9328
# Epoch [1/3], Step [4300/12942], Loss: 2.6097, Perplexity: 13.5948
# Epoch [1/3], Step [4400/12942], Loss: 2.4901, Perplexity: 12.0625
# Epoch [1/3], Step [4500/12942], Loss: 2.6971, Perplexity: 14.8366
# Epoch [1/3], Step [4600/12942], Loss: 2.7100, Perplexity: 15.0290
# Epoch [1/3], Step [4700/12942], Loss: 2.8584, Perplexity: 17.4340
# Epoch [1/3], Step [4800/12942], Loss: 3.0004, Perplexity: 20.0930
# Epoch [1/3], Step [4900/12942], Loss: 2.5941, Perplexity: 13.3843
# Epoch [1/3], Step [5000/12942], Loss: 2.8686, Perplexity: 17.6129
# Epoch [1/3], Step [5100/12942], Loss: 2.6463, Perplexity: 14.1011
# Epoch [1/3], Step [5200/12942], Loss: 2.7122, Perplexity: 15.0621
# Epoch [1/3], Step [5300/12942], Loss: 2.0360, Perplexity: 7.66024
# Epoch [1/3], Step [5400/12942], Loss: 2.6406, Perplexity: 14.0211
# Epoch [1/3], Step [5500/12942], Loss: 2.8450, Perplexity: 17.2011
# Epoch [1/3], Step [5600/12942], Loss: 2.4094, Perplexity: 11.1269
# Epoch [1/3], Step [5700/12942], Loss: 2.9925, Perplexity: 19.9349
# Epoch [1/3], Step [5800/12942], Loss: 3.0216, Perplexity: 20.5238
# Epoch [1/3], Step [5900/12942], Loss: 2.7295, Perplexity: 15.3246
# Epoch [1/3], Step [6000/12942], Loss: 2.2649, Perplexity: 9.62999
# Epoch [1/3], Step [6100/12942], Loss: 2.9712, Perplexity: 19.5144
# Epoch [1/3], Step [6200/12942], Loss: 2.2699, Perplexity: 9.67866
# Epoch [1/3], Step [6300/12942], Loss: 2.4526, Perplexity: 11.6187
# Epoch [1/3], Step [6400/12942], Loss: 2.5244, Perplexity: 12.4831
# Epoch [1/3], Step [6500/12942], Loss: 2.7143, Perplexity: 15.0937
# Epoch [1/3], Step [6600/12942], Loss: 2.5654, Perplexity: 13.0064
# Epoch [1/3], Step [6700/12942], Loss: 2.5671, Perplexity: 13.0279
# Epoch [1/3], Step [6800/12942], Loss: 2.5613, Perplexity: 12.9524
# Epoch [1/3], Step [6900/12942], Loss: 2.6432, Perplexity: 14.0577
# Epoch [1/3], Step [7000/12942], Loss: 2.7818, Perplexity: 16.1483
# Epoch [1/3], Step [7100/12942], Loss: 2.7309, Perplexity: 15.3473
# Epoch [1/3], Step [7200/12942], Loss: 2.4232, Perplexity: 11.2822
# Epoch [1/3], Step [7300/12942], Loss: 2.7482, Perplexity: 15.6148
# Epoch [1/3], Step [7400/12942], Loss: 2.4491, Perplexity: 11.5776
# Epoch [1/3], Step [7500/12942], Loss: 2.5326, Perplexity: 12.5860
# Epoch [1/3], Step [7600/12942], Loss: 2.7489, Perplexity: 15.6258
# Epoch [1/3], Step [7700/12942], Loss: 2.7206, Perplexity: 15.1892
# Epoch [1/3], Step [7800/12942], Loss: 2.5709, Perplexity: 13.0772
# Epoch [1/3], Step [7900/12942], Loss: 2.7095, Perplexity: 15.0215
# Epoch [1/3], Step [8000/12942], Loss: 2.7632, Perplexity: 15.8508
# Epoch [1/3], Step [8100/12942], Loss: 2.4701, Perplexity: 11.8238
# Epoch [1/3], Step [8200/12942], Loss: 4.2278, Perplexity: 68.5677
# Epoch [1/3], Step [8300/12942], Loss: 2.5798, Perplexity: 13.1949
# Epoch [1/3], Step [8400/12942], Loss: 2.3456, Perplexity: 10.4391
# Epoch [1/3], Step [8500/12942], Loss: 2.6336, Perplexity: 13.9245
# Epoch [1/3], Step [8600/12942], Loss: 2.4000, Perplexity: 11.0231
# Epoch [1/3], Step [8700/12942], Loss: 2.8453, Perplexity: 17.2064
# Epoch [1/3], Step [8800/12942], Loss: 2.7828, Perplexity: 16.1641
# Epoch [1/3], Step [8900/12942], Loss: 2.7354, Perplexity: 15.4164
# Epoch [1/3], Step [9000/12942], Loss: 2.4804, Perplexity: 11.9455
# Epoch [1/3], Step [9100/12942], Loss: 2.7869, Perplexity: 16.2309
# Epoch [1/3], Step [9200/12942], Loss: 2.6362, Perplexity: 13.9604
# Epoch [1/3], Step [9300/12942], Loss: 2.7288, Perplexity: 15.3139
# Epoch [1/3], Step [9400/12942], Loss: 2.3517, Perplexity: 10.5037
# Epoch [1/3], Step [9500/12942], Loss: 2.2174, Perplexity: 9.18374
# Epoch [1/3], Step [9600/12942], Loss: 2.6275, Perplexity: 13.8388
# Epoch [1/3], Step [9700/12942], Loss: 2.6421, Perplexity: 14.0425
# Epoch [1/3], Step [9800/12942], Loss: 2.1108, Perplexity: 8.254576
# Epoch [1/3], Step [9900/12942], Loss: 2.7683, Perplexity: 15.93180
# Epoch [1/3], Step [10000/12942], Loss: 2.4930, Perplexity: 12.0979
# Epoch [1/3], Step [10100/12942], Loss: 2.6180, Perplexity: 13.7078
# Epoch [1/3], Step [10200/12942], Loss: 2.6026, Perplexity: 13.4984
# Epoch [1/3], Step [10300/12942], Loss: 2.0886, Perplexity: 8.07322
# Epoch [1/3], Step [10400/12942], Loss: 2.4160, Perplexity: 11.2004
# Epoch [1/3], Step [10500/12942], Loss: 2.1674, Perplexity: 8.73528
# Epoch [1/3], Step [10600/12942], Loss: 2.9714, Perplexity: 19.5197
# Epoch [1/3], Step [10700/12942], Loss: 2.4441, Perplexity: 11.5199
# Epoch [1/3], Step [10800/12942], Loss: 2.4074, Perplexity: 11.1048
# Epoch [1/3], Step [10900/12942], Loss: 2.4742, Perplexity: 11.8723
# Epoch [1/3], Step [11000/12942], Loss: 2.5506, Perplexity: 12.8153
# Epoch [1/3], Step [11100/12942], Loss: 2.4862, Perplexity: 12.0160
# Epoch [1/3], Step [11200/12942], Loss: 2.3809, Perplexity: 10.8148
# Epoch [1/3], Step [11300/12942], Loss: 2.2786, Perplexity: 9.76336
# Epoch [1/3], Step [11400/12942], Loss: 2.4898, Perplexity: 12.05849
# Epoch [1/3], Step [11500/12942], Loss: 2.3861, Perplexity: 10.8709
# Epoch [1/3], Step [11600/12942], Loss: 2.4070, Perplexity: 11.1005
# Epoch [1/3], Step [11700/12942], Loss: 2.8456, Perplexity: 17.2115
# Epoch [1/3], Step [11800/12942], Loss: 2.1452, Perplexity: 8.54351
# Epoch [1/3], Step [11900/12942], Loss: 2.7111, Perplexity: 15.0460
# Epoch [1/3], Step [12000/12942], Loss: 2.8249, Perplexity: 16.8588
# Epoch [1/3], Step [12100/12942], Loss: 2.5777, Perplexity: 13.1663
# Epoch [1/3], Step [12200/12942], Loss: 2.1625, Perplexity: 8.69318
# Epoch [1/3], Step [12300/12942], Loss: 2.3553, Perplexity: 10.5411
# Epoch [1/3], Step [12400/12942], Loss: 2.3196, Perplexity: 10.1712
# Epoch [1/3], Step [12500/12942], Loss: 2.2268, Perplexity: 9.26985
# Epoch [1/3], Step [12600/12942], Loss: 2.3382, Perplexity: 10.3627
# Epoch [1/3], Step [12700/12942], Loss: 2.4506, Perplexity: 11.5954
# Epoch [1/3], Step [12800/12942], Loss: 2.3370, Perplexity: 10.3498
# Epoch [1/3], Step [12900/12942], Loss: 2.7336, Perplexity: 15.3889
# Epoch [2/3], Step [100/12942], Loss: 2.1520, Perplexity: 8.6017793
# Epoch [2/3], Step [200/12942], Loss: 2.2797, Perplexity: 9.77355
# Epoch [2/3], Step [300/12942], Loss: 2.2699, Perplexity: 9.67866
# Epoch [2/3], Step [400/12942], Loss: 2.6219, Perplexity: 13.7625
# Epoch [2/3], Step [500/12942], Loss: 2.1026, Perplexity: 8.18716
# Epoch [2/3], Step [600/12942], Loss: 2.2603, Perplexity: 9.58644
# Epoch [2/3], Step [700/12942], Loss: 2.2061, Perplexity: 9.08079
# Epoch [2/3], Step [800/12942], Loss: 2.1831, Perplexity: 8.87359
# Epoch [2/3], Step [900/12942], Loss: 2.3208, Perplexity: 10.1842
# Epoch [2/3], Step [1000/12942], Loss: 1.9511, Perplexity: 7.0366
# Epoch [2/3], Step [1100/12942], Loss: 2.2329, Perplexity: 9.326458
# Epoch [2/3], Step [1200/12942], Loss: 2.7259, Perplexity: 15.2696
# Epoch [2/3], Step [1300/12942], Loss: 2.1870, Perplexity: 8.90884
# Epoch [2/3], Step [1400/12942], Loss: 2.2919, Perplexity: 9.89425
# Epoch [2/3], Step [1500/12942], Loss: 2.0300, Perplexity: 7.61401
# Epoch [2/3], Step [1600/12942], Loss: 2.5687, Perplexity: 13.0490
# Epoch [2/3], Step [1700/12942], Loss: 2.4941, Perplexity: 12.1108
# Epoch [2/3], Step [1800/12942], Loss: 2.5704, Perplexity: 13.0705
# Epoch [2/3], Step [1900/12942], Loss: 2.9662, Perplexity: 19.4177
# Epoch [2/3], Step [2000/12942], Loss: 2.0572, Perplexity: 7.82382
# Epoch [2/3], Step [2100/12942], Loss: 2.2213, Perplexity: 9.21904
# Epoch [2/3], Step [2200/12942], Loss: 2.3006, Perplexity: 9.98054
# Epoch [2/3], Step [2300/12942], Loss: 2.2472, Perplexity: 9.46112
# Epoch [2/3], Step [2400/12942], Loss: 2.4940, Perplexity: 12.1092
# Epoch [2/3], Step [2500/12942], Loss: 2.2150, Perplexity: 9.16115
# Epoch [2/3], Step [2600/12942], Loss: 2.4213, Perplexity: 11.2602
# Epoch [2/3], Step [2700/12942], Loss: 2.5136, Perplexity: 12.3489
# Epoch [2/3], Step [2800/12942], Loss: 2.3275, Perplexity: 10.2523
# Epoch [2/3], Step [2900/12942], Loss: 2.4246, Perplexity: 11.2973
# Epoch [2/3], Step [3000/12942], Loss: 2.3118, Perplexity: 10.0921
# Epoch [2/3], Step [3100/12942], Loss: 2.3545, Perplexity: 10.5332
# Epoch [2/3], Step [3200/12942], Loss: 2.3743, Perplexity: 10.7435
# Epoch [2/3], Step [3300/12942], Loss: 2.6742, Perplexity: 14.5005
# Epoch [2/3], Step [3400/12942], Loss: 2.4336, Perplexity: 11.3996
# Epoch [2/3], Step [3500/12942], Loss: 2.4526, Perplexity: 11.6187
# Epoch [2/3], Step [3600/12942], Loss: 2.7276, Perplexity: 15.2968
# Epoch [2/3], Step [3700/12942], Loss: 2.1955, Perplexity: 8.98410
# Epoch [2/3], Step [3800/12942], Loss: 2.4722, Perplexity: 11.8490
# Epoch [2/3], Step [3900/12942], Loss: 2.3004, Perplexity: 9.97802
# Epoch [2/3], Step [4000/12942], Loss: 2.3271, Perplexity: 10.2485
# Epoch [2/3], Step [4100/12942], Loss: 2.3567, Perplexity: 10.5566
# Epoch [2/3], Step [4200/12942], Loss: 2.5840, Perplexity: 13.2501
# Epoch [2/3], Step [4300/12942], Loss: 2.4724, Perplexity: 11.8503
# Epoch [2/3], Step [4400/12942], Loss: 2.6135, Perplexity: 13.6463
# Epoch [2/3], Step [4500/12942], Loss: 2.0390, Perplexity: 7.68272
# Epoch [2/3], Step [4600/12942], Loss: 2.6619, Perplexity: 14.3233
# Epoch [2/3], Step [4700/12942], Loss: 2.2418, Perplexity: 9.41065
# Epoch [2/3], Step [4800/12942], Loss: 2.3325, Perplexity: 10.3040
# Epoch [2/3], Step [4900/12942], Loss: 2.3098, Perplexity: 10.0723
# Epoch [2/3], Step [5000/12942], Loss: 2.4697, Perplexity: 11.8187
# Epoch [2/3], Step [5100/12942], Loss: 2.2830, Perplexity: 9.80659
# Epoch [2/3], Step [5200/12942], Loss: 2.3647, Perplexity: 10.6405
# Epoch [2/3], Step [5300/12942], Loss: 2.2422, Perplexity: 9.41365
# Epoch [2/3], Step [5400/12942], Loss: 1.9744, Perplexity: 7.20213
# Epoch [2/3], Step [5500/12942], Loss: 2.4623, Perplexity: 11.7322
# Epoch [2/3], Step [5600/12942], Loss: 2.3624, Perplexity: 10.6163
# Epoch [2/3], Step [5700/12942], Loss: 2.3104, Perplexity: 10.0789
# Epoch [2/3], Step [5800/12942], Loss: 2.3193, Perplexity: 10.1681
# Epoch [2/3], Step [5900/12942], Loss: 2.7485, Perplexity: 15.6196
# Epoch [2/3], Step [6000/12942], Loss: 2.1425, Perplexity: 8.52082
# Epoch [2/3], Step [6100/12942], Loss: 2.3424, Perplexity: 10.4061
# Epoch [2/3], Step [6200/12942], Loss: 2.4553, Perplexity: 11.6497
# Epoch [2/3], Step [6300/12942], Loss: 2.0061, Perplexity: 7.43404
# Epoch [2/3], Step [6400/12942], Loss: 2.2128, Perplexity: 9.141576
# Epoch [2/3], Step [6500/12942], Loss: 2.1509, Perplexity: 8.59235
# Epoch [2/3], Step [6600/12942], Loss: 2.1110, Perplexity: 8.25689
# Epoch [2/3], Step [6700/12942], Loss: 2.1158, Perplexity: 8.29618
# Epoch [2/3], Step [6800/12942], Loss: 2.0629, Perplexity: 7.86903
# Epoch [2/3], Step [6900/12942], Loss: 2.5342, Perplexity: 12.6062
# Epoch [2/3], Step [7000/12942], Loss: 2.2836, Perplexity: 9.81246
# Epoch [2/3], Step [7100/12942], Loss: 2.4009, Perplexity: 11.0327
# Epoch [2/3], Step [7200/12942], Loss: 2.2317, Perplexity: 9.31570
# Epoch [2/3], Step [7300/12942], Loss: 2.5443, Perplexity: 12.7338
# Epoch [2/3], Step [7400/12942], Loss: 2.1310, Perplexity: 8.42294
# Epoch [2/3], Step [7500/12942], Loss: 2.2429, Perplexity: 9.42025
# Epoch [2/3], Step [7600/12942], Loss: 2.2381, Perplexity: 9.37555
# Epoch [2/3], Step [7700/12942], Loss: 2.4600, Perplexity: 11.7047
# Epoch [2/3], Step [7800/12942], Loss: 2.4048, Perplexity: 11.0762
# Epoch [2/3], Step [7900/12942], Loss: 2.3257, Perplexity: 10.2334
# Epoch [2/3], Step [8000/12942], Loss: 2.3015, Perplexity: 9.98886
# Epoch [2/3], Step [8100/12942], Loss: 2.3889, Perplexity: 10.9018
# Epoch [2/3], Step [8200/12942], Loss: 2.1097, Perplexity: 8.24603
# Epoch [2/3], Step [8300/12942], Loss: 2.3160, Perplexity: 10.1346
# Epoch [2/3], Step [8400/12942], Loss: 2.0948, Perplexity: 8.12368
# Epoch [2/3], Step [8500/12942], Loss: 2.2222, Perplexity: 9.22745
# Epoch [2/3], Step [8600/12942], Loss: 2.2220, Perplexity: 9.22588
# Epoch [2/3], Step [8700/12942], Loss: 2.1970, Perplexity: 8.99807
# Epoch [2/3], Step [8800/12942], Loss: 2.0035, Perplexity: 7.41509
# Epoch [2/3], Step [8900/12942], Loss: 2.2202, Perplexity: 9.20957
# Epoch [2/3], Step [9000/12942], Loss: 2.4168, Perplexity: 11.2104
# Epoch [2/3], Step [9100/12942], Loss: 2.3799, Perplexity: 10.8033
# Epoch [2/3], Step [9200/12942], Loss: 2.2242, Perplexity: 9.24603
# Epoch [2/3], Step [9300/12942], Loss: 2.1880, Perplexity: 8.91721
# Epoch [2/3], Step [9400/12942], Loss: 2.0364, Perplexity: 7.66331
# Epoch [2/3], Step [9500/12942], Loss: 2.3266, Perplexity: 10.2435
# Epoch [2/3], Step [9600/12942], Loss: 2.2260, Perplexity: 9.26301
# Epoch [2/3], Step [9700/12942], Loss: 2.2149, Perplexity: 9.16016
# Epoch [2/3], Step [9800/12942], Loss: 2.0839, Perplexity: 8.03586
# Epoch [2/3], Step [9900/12942], Loss: 2.1752, Perplexity: 8.80406
# Epoch [2/3], Step [10000/12942], Loss: 1.9356, Perplexity: 6.9285
# Epoch [2/3], Step [10100/12942], Loss: 2.2185, Perplexity: 9.19343
# Epoch [2/3], Step [10200/12942], Loss: 2.1470, Perplexity: 8.55937
# Epoch [2/3], Step [10300/12942], Loss: 2.2169, Perplexity: 9.17854
# Epoch [2/3], Step [10400/12942], Loss: 2.0863, Perplexity: 8.05523
# Epoch [2/3], Step [10500/12942], Loss: 2.9288, Perplexity: 18.7045
# Epoch [2/3], Step [10600/12942], Loss: 2.0773, Perplexity: 7.98255
# Epoch [2/3], Step [10700/12942], Loss: 2.0345, Perplexity: 7.64838
# Epoch [2/3], Step [10800/12942], Loss: 1.9851, Perplexity: 7.28003
# Epoch [2/3], Step [10900/12942], Loss: 2.0330, Perplexity: 7.63677
# Epoch [2/3], Step [11000/12942], Loss: 2.2087, Perplexity: 9.10349
# Epoch [2/3], Step [11100/12942], Loss: 2.3675, Perplexity: 10.6708
# Epoch [2/3], Step [11200/12942], Loss: 2.3852, Perplexity: 10.8617
# Epoch [2/3], Step [11300/12942], Loss: 1.8113, Perplexity: 6.11827
# Epoch [2/3], Step [11400/12942], Loss: 1.9455, Perplexity: 6.99739
# Epoch [2/3], Step [11500/12942], Loss: 2.0418, Perplexity: 7.70412
# Epoch [2/3], Step [11600/12942], Loss: 2.1011, Perplexity: 8.17542
# Epoch [2/3], Step [11700/12942], Loss: 2.3546, Perplexity: 10.5338
# Epoch [2/3], Step [11800/12942], Loss: 2.0167, Perplexity: 7.51382
# Epoch [2/3], Step [11900/12942], Loss: 2.3171, Perplexity: 10.1464
# Epoch [2/3], Step [12000/12942], Loss: 2.0856, Perplexity: 8.04962
# Epoch [2/3], Step [12100/12942], Loss: 2.0462, Perplexity: 7.73823
# Epoch [2/3], Step [12200/12942], Loss: 2.3202, Perplexity: 10.1780
# Epoch [2/3], Step [12300/12942], Loss: 2.1010, Perplexity: 8.17423
# Epoch [2/3], Step [12400/12942], Loss: 1.8782, Perplexity: 6.54161
# Epoch [2/3], Step [12500/12942], Loss: 1.8810, Perplexity: 6.55999
# Epoch [2/3], Step [12600/12942], Loss: 2.1926, Perplexity: 8.95830
# Epoch [2/3], Step [12700/12942], Loss: 2.0789, Perplexity: 7.99540
# Epoch [2/3], Step [12800/12942], Loss: 2.2239, Perplexity: 9.24371
# Epoch [2/3], Step [12900/12942], Loss: 2.3673, Perplexity: 10.6682
# Epoch [3/3], Step [100/12942], Loss: 2.1842, Perplexity: 8.88403206
# Epoch [3/3], Step [200/12942], Loss: 2.4629, Perplexity: 11.7384
# Epoch [3/3], Step [300/12942], Loss: 2.1753, Perplexity: 8.80452
# Epoch [3/3], Step [400/12942], Loss: 2.3939, Perplexity: 10.9563
# Epoch [3/3], Step [500/12942], Loss: 2.5830, Perplexity: 13.2364
# Epoch [3/3], Step [600/12942], Loss: 2.9912, Perplexity: 19.9103
# Epoch [3/3], Step [700/12942], Loss: 2.1632, Perplexity: 8.69919
# Epoch [3/3], Step [800/12942], Loss: 2.2439, Perplexity: 9.43025
# Epoch [3/3], Step [900/12942], Loss: 2.3117, Perplexity: 10.0916
# Epoch [3/3], Step [1000/12942], Loss: 2.1382, Perplexity: 8.4841
# Epoch [3/3], Step [1100/12942], Loss: 2.1280, Perplexity: 8.39819
# Epoch [3/3], Step [1200/12942], Loss: 2.5951, Perplexity: 13.3985
# Epoch [3/3], Step [1300/12942], Loss: 1.9776, Perplexity: 7.225366
# Epoch [3/3], Step [1400/12942], Loss: 2.0574, Perplexity: 7.82594
# Epoch [3/3], Step [1500/12942], Loss: 2.1932, Perplexity: 8.96410
# Epoch [3/3], Step [1600/12942], Loss: 2.3715, Perplexity: 10.7138
# Epoch [3/3], Step [1700/12942], Loss: 2.4699, Perplexity: 11.8208
# Epoch [3/3], Step [1800/12942], Loss: 2.3801, Perplexity: 10.8063
# Epoch [3/3], Step [1900/12942], Loss: 2.1601, Perplexity: 8.67196
# Epoch [3/3], Step [2000/12942], Loss: 2.2992, Perplexity: 9.96582
# Epoch [3/3], Step [2100/12942], Loss: 2.5677, Perplexity: 13.0360
# Epoch [3/3], Step [2200/12942], Loss: 3.0779, Perplexity: 21.7136
# Epoch [3/3], Step [2300/12942], Loss: 2.1507, Perplexity: 8.59075
# Epoch [3/3], Step [2400/12942], Loss: 2.3135, Perplexity: 10.1095
# Epoch [3/3], Step [2500/12942], Loss: 2.1776, Perplexity: 8.82546
# Epoch [3/3], Step [2600/12942], Loss: 2.1586, Perplexity: 8.65926
# Epoch [3/3], Step [2700/12942], Loss: 1.9079, Perplexity: 6.73874
# Epoch [3/3], Step [2800/12942], Loss: 2.0663, Perplexity: 7.89546
# Epoch [3/3], Step [2900/12942], Loss: 2.2279, Perplexity: 9.28023
# Epoch [3/3], Step [3000/12942], Loss: 2.1543, Perplexity: 8.62223
# Epoch [3/3], Step [3100/12942], Loss: 2.2010, Perplexity: 9.03410
# Epoch [3/3], Step [3200/12942], Loss: 2.4193, Perplexity: 11.2384
# Epoch [3/3], Step [3300/12942], Loss: 2.4167, Perplexity: 11.2089
# Epoch [3/3], Step [3400/12942], Loss: 3.3331, Perplexity: 28.0251
# Epoch [3/3], Step [3500/12942], Loss: 2.3732, Perplexity: 10.7321
# Epoch [3/3], Step [3600/12942], Loss: 2.1087, Perplexity: 8.23733
# Epoch [3/3], Step [3700/12942], Loss: 2.0789, Perplexity: 7.99596
# Epoch [3/3], Step [3800/12942], Loss: 2.1346, Perplexity: 8.45350
# Epoch [3/3], Step [3900/12942], Loss: 1.9720, Perplexity: 7.18517
# Epoch [3/3], Step [4000/12942], Loss: 2.0441, Perplexity: 7.72236
# Epoch [3/3], Step [4100/12942], Loss: 2.4930, Perplexity: 12.0975
# Epoch [3/3], Step [4200/12942], Loss: 2.4818, Perplexity: 11.9624
# Epoch [3/3], Step [4300/12942], Loss: 2.2066, Perplexity: 9.08506
# Epoch [3/3], Step [4400/12942], Loss: 2.1944, Perplexity: 8.97496
# Epoch [3/3], Step [4500/12942], Loss: 2.4068, Perplexity: 11.0979
# Epoch [3/3], Step [4600/12942], Loss: 2.6363, Perplexity: 13.9610
# Epoch [3/3], Step [4700/12942], Loss: 2.0257, Perplexity: 7.58158
# Epoch [3/3], Step [4800/12942], Loss: 2.2765, Perplexity: 9.74241
# Epoch [3/3], Step [4900/12942], Loss: 1.9280, Perplexity: 6.87576
# Epoch [3/3], Step [5000/12942], Loss: 2.2755, Perplexity: 9.73253
# Epoch [3/3], Step [5100/12942], Loss: 1.9760, Perplexity: 7.21379
# Epoch [3/3], Step [5200/12942], Loss: 1.8988, Perplexity: 6.67829
# Epoch [3/3], Step [5300/12942], Loss: 2.3247, Perplexity: 10.2235
# Epoch [3/3], Step [5400/12942], Loss: 2.0232, Perplexity: 7.56280
# Epoch [3/3], Step [5500/12942], Loss: 2.2415, Perplexity: 9.40700
# Epoch [3/3], Step [5600/12942], Loss: 2.2306, Perplexity: 9.30563
# Epoch [3/3], Step [5700/12942], Loss: 2.7900, Perplexity: 16.2807
# Epoch [3/3], Step [5800/12942], Loss: 2.2858, Perplexity: 9.83405
# Epoch [3/3], Step [5900/12942], Loss: 2.0949, Perplexity: 8.12491
# Epoch [3/3], Step [6000/12942], Loss: 1.9360, Perplexity: 6.93074
# Epoch [3/3], Step [6100/12942], Loss: 2.2427, Perplexity: 9.41851
# Epoch [3/3], Step [6200/12942], Loss: 2.3400, Perplexity: 10.3811
# Epoch [3/3], Step [6300/12942], Loss: 2.1351, Perplexity: 8.45765
# Epoch [3/3], Step [6400/12942], Loss: 2.1814, Perplexity: 8.85853
# Epoch [3/3], Step [6500/12942], Loss: 2.0183, Perplexity: 7.52564
# Epoch [3/3], Step [6600/12942], Loss: 1.8900, Perplexity: 6.61916
# Epoch [3/3], Step [6700/12942], Loss: 2.1304, Perplexity: 8.41866
# Epoch [3/3], Step [6800/12942], Loss: 2.0035, Perplexity: 7.41538
# Epoch [3/3], Step [6900/12942], Loss: 2.1792, Perplexity: 8.83890
# Epoch [3/3], Step [7000/12942], Loss: 1.8011, Perplexity: 6.05642
# Epoch [3/3], Step [7100/12942], Loss: 2.1355, Perplexity: 8.46148
# Epoch [3/3], Step [7200/12942], Loss: 2.1515, Perplexity: 8.59745
# Epoch [3/3], Step [7300/12942], Loss: 2.4123, Perplexity: 11.1591
# Epoch [3/3], Step [7400/12942], Loss: 2.5530, Perplexity: 12.8462
# Epoch [3/3], Step [7500/12942], Loss: 2.1768, Perplexity: 8.81812
# Epoch [3/3], Step [7600/12942], Loss: 2.1605, Perplexity: 8.67517
# Epoch [3/3], Step [7700/12942], Loss: 2.1336, Perplexity: 8.44530
# Epoch [3/3], Step [7800/12942], Loss: 2.1442, Perplexity: 8.53536
# Epoch [3/3], Step [7900/12942], Loss: 1.9753, Perplexity: 7.20884
# Epoch [3/3], Step [8000/12942], Loss: 2.1795, Perplexity: 8.84170
# Epoch [3/3], Step [8100/12942], Loss: 2.4159, Perplexity: 11.2000
# Epoch [3/3], Step [8200/12942], Loss: 2.1853, Perplexity: 8.89371
# Epoch [3/3], Step [8300/12942], Loss: 2.1993, Perplexity: 9.01840
# Epoch [3/3], Step [8400/12942], Loss: 2.5796, Perplexity: 13.1917
# Epoch [3/3], Step [8500/12942], Loss: 2.4835, Perplexity: 11.9837
# Epoch [3/3], Step [8600/12942], Loss: 2.5405, Perplexity: 12.6860
# Epoch [3/3], Step [8700/12942], Loss: 2.0877, Perplexity: 8.06663
# Epoch [3/3], Step [8800/12942], Loss: 2.0424, Perplexity: 7.70931
# Epoch [3/3], Step [8900/12942], Loss: 2.1975, Perplexity: 9.00210
# Epoch [3/3], Step [9000/12942], Loss: 2.1481, Perplexity: 8.56839
# Epoch [3/3], Step [9100/12942], Loss: 2.1684, Perplexity: 8.74457
# Epoch [3/3], Step [9200/12942], Loss: 2.2028, Perplexity: 9.05071
# Epoch [3/3], Step [9300/12942], Loss: 2.2546, Perplexity: 9.53186
# Epoch [3/3], Step [9400/12942], Loss: 2.1311, Perplexity: 8.42435
# Epoch [3/3], Step [9500/12942], Loss: 2.1869, Perplexity: 8.90783
# Epoch [3/3], Step [9600/12942], Loss: 2.2248, Perplexity: 9.25158
# Epoch [3/3], Step [9700/12942], Loss: 2.2306, Perplexity: 9.30550
# Epoch [3/3], Step [9800/12942], Loss: 2.8081, Perplexity: 16.5791
# Epoch [3/3], Step [9900/12942], Loss: 2.0691, Perplexity: 7.91769
# Epoch [3/3], Step [10000/12942], Loss: 2.0640, Perplexity: 7.8775
# Epoch [3/3], Step [10100/12942], Loss: 2.1212, Perplexity: 8.34081
# Epoch [3/3], Step [10200/12942], Loss: 2.3702, Perplexity: 10.6996
# Epoch [3/3], Step [10300/12942], Loss: 2.8054, Perplexity: 16.5338
# Epoch [3/3], Step [10400/12942], Loss: 2.3200, Perplexity: 10.1758
# Epoch [3/3], Step [10500/12942], Loss: 1.9112, Perplexity: 6.76111
# Epoch [3/3], Step [10600/12942], Loss: 2.7496, Perplexity: 15.6368
# Epoch [3/3], Step [10700/12942], Loss: 2.1025, Perplexity: 8.18640
# Epoch [3/3], Step [10800/12942], Loss: 2.1934, Perplexity: 8.96522
# Epoch [3/3], Step [10900/12942], Loss: 2.3255, Perplexity: 10.2319
# Epoch [3/3], Step [11000/12942], Loss: 2.1439, Perplexity: 8.53230
# Epoch [3/3], Step [11100/12942], Loss: 2.3316, Perplexity: 10.2947
# Epoch [3/3], Step [11200/12942], Loss: 2.5042, Perplexity: 12.2341
# Epoch [3/3], Step [11300/12942], Loss: 2.0362, Perplexity: 7.66117
# Epoch [3/3], Step [11400/12942], Loss: 2.4522, Perplexity: 11.6144
# Epoch [3/3], Step [11500/12942], Loss: 2.6800, Perplexity: 14.5846
# Epoch [3/3], Step [11600/12942], Loss: 2.1848, Perplexity: 8.88870
# Epoch [3/3], Step [11700/12942], Loss: 2.8944, Perplexity: 18.0728
# Epoch [3/3], Step [11800/12942], Loss: 2.2254, Perplexity: 9.25687
# Epoch [3/3], Step [11900/12942], Loss: 1.8905, Perplexity: 6.62273
# Epoch [3/3], Step [12000/12942], Loss: 2.0559, Perplexity: 7.81375
# Epoch [3/3], Step [12100/12942], Loss: 2.4806, Perplexity: 11.9480
# Epoch [3/3], Step [12200/12942], Loss: 2.2496, Perplexity: 9.48380
# Epoch [3/3], Step [12300/12942], Loss: 2.2588, Perplexity: 9.57191
# Epoch [3/3], Step [12400/12942], Loss: 1.9371, Perplexity: 6.93840
# Epoch [3/3], Step [12500/12942], Loss: 2.0257, Perplexity: 7.58188
# Epoch [3/3], Step [12600/12942], Loss: 1.7635, Perplexity: 5.83303
# Epoch [3/3], Step [12700/12942], Loss: 2.1138, Perplexity: 8.27987
# Epoch [3/3], Step [12800/12942], Loss: 1.9604, Perplexity: 7.10223
# Epoch [3/3], Step [12900/12942], Loss: 1.8911, Perplexity: 6.62665
# Epoch [3/3], Step [12942/12942], Loss: 2.0539, Perplexity: 7.79790

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
